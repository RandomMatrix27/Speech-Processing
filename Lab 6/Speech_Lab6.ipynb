# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Load an audio file
file_path = "C:/Users/Sreyas/Desktop/speech1.ogg"
y, sr = librosa.load(file_path)

# Display the waveform
librosa.display.waveshow(y, sr=sr)
plt.title('Waveform')
plt.show()

# %%
import IPython.display as ipd

print("Original Audio:")
ipd.display(ipd.Audio(y, rate=sr))
# Out:
# Original Audio:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(len(y))
# Out:
# 60662

# %%
A_sound=y[8000:16000]
ipd.display(ipd.Audio(A_sound,rate=sr))

plt.figure(figsize=(10, 4))
plt.plot(A_sound)
plt.title('Amplitude Spectrum')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np 
import matplotlib.pyplot as plt

fft_A=np.fft.fft(seg1)
A_amp_spectrum=np.abs(fft_A)

ipd.display(ipd.Audio(fft_A,rate=sr))

plt.figure(figsize=(10, 4))
plt.plot(A_amp_spectrum,"red")
plt.title('Amplitude Spectrum')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
I_sound= y[16000:21000]
ipd.display(ipd.Audio(I_sound,rate=sr))
plt.figure(figsize=(10, 4))
plt.plot(I_sound,"indigo")
plt.title('Amplitude Spectrum I')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fft_I=np.fft.fft(I_sound)
I_amp_spectrum=np.abs(fft_I)

ipd.display(ipd.Audio(fft_I,rate=sr))

plt.figure(figsize=(10, 4))
plt.plot(I_amp_spectrum,"indigo")
plt.title('Amplitude Spectrum I')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
E_sound= y[34500:37000]

ipd.display(ipd.Audio(E_sound,rate=sr))

plt.figure(figsize=(10, 4))
plt.plot(E_sound,"green")
plt.title('Amplitude Spectrum of E')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fft_E=np.fft.fft(E_sound)
E_amp_spectrum=np.abs(fft_E)

ipd.display(ipd.Audio(fft_E,rate=sr))

plt.figure(figsize=(10, 4))
plt.plot(E_amp_spectrum,"green")
plt.title('Amplitude Spectrum E')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ch_sound= y[37000:39000]

ipd.display(ipd.Audio(ch_sound,rate=sr))

plt.figure(figsize=(10, 4))
plt.plot(E_sound,"green")
plt.title('Amplitude Spectrum of ch')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fft_ch=np.fft.fft(ch_sound)
ch_amp_spectrum=np.abs(fft_ch)

ipd.display(ipd.Audio(fft_ch,rate=sr))

plt.figure(figsize=(10, 4))
plt.plot(ch_amp_spectrum,"green")
plt.title('Amplitude Spectrum ch')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sp_sound= y[31000:34000]

ipd.display(ipd.Audio(sp_sound,rate=sr))

plt.figure(figsize=(10, 4))
plt.plot(E_sound,"maroon")
plt.title('Amplitude Spectrum of sp')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fft_sp=np.fft.fft(sp_sound)
sp_amp_spectrum=np.abs(fft_sp)

ipd.display(ipd.Audio(fft_sp,rate=sr))

plt.figure(figsize=(10, 4))
plt.plot(sp_amp_spectrum,"green")
plt.title('Amplitude Spectrum sp')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sile1=y[:3680]

ipd.display(ipd.Audio(sile1,rate=sr))

plt.figure(figsize=(10, 4))
plt.plot(sile1,"maroon")
plt.title('Amplitude Spectrum of silence')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fft_sile1=np.fft.fft(sile1)
sile1_amp_spectrum=np.abs(fft_sile1)

ipd.display(ipd.Audio(fft_sile1,rate=sr))

plt.figure(figsize=(10, 4))
plt.plot(sile1_amp_spectrum,"green")
plt.title('Amplitude Spectrum sile1')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
noise1=y[4000:8000]

ipd.display(ipd.Audio(noise1,rate=sr))

plt.figure(figsize=(10, 4))
plt.plot(noise1,"maroon")
plt.title('Amplitude Spectrum of silence')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fft_noise1=np.fft.fft(noise1)
noise1_amp_spectrum=np.abs(fft_noise1)

ipd.display(ipd.Audio(fft_noise1,rate=sr))

plt.figure(figsize=(10, 4))
plt.plot(noise1_amp_spectrum,"green")
plt.title('Amplitude Spectrum noise1')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
D = librosa.stft(y)
S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)
S_db.shape
(1025, 153)
# Plot the transformed audio data
fig, ax = plt.subplots(figsize=(10, 5))
img = librosa.display.specshow(S_db,
                              x_axis='time',
                              y_axis='log',
                              ax=ax)
ax.set_title('Spectogram Example', fontsize=20)
fig.colorbar(img, ax=ax, format=f'%0.2f')
plt.show()

# %%
def generate_spectrogram(signal, sample_rate):
    plt.specgram(signal, Fs=sample_rate)
    plt.title("Spectrogram of Speech Signal")
    plt.xlabel("Time (s)")
    plt.ylabel("Frequency (Hz)")
    plt.colorbar()

# Generate spectrogram
plt.figure(figsize=(12, 6))
generate_spectrogram(y,sr)
plt.show()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:7773: RuntimeWarning: divide by zero encountered in log10
#   Z = 10. * np.log10(spec)
